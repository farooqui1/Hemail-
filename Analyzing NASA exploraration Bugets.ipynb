# %% [markdown]
# # Analyzing NASA Planetary Exploration Budgets

# %% [markdown]
# First we will check all our tables

# %%
SELECT *
FROM inflation
# Out:
#    fiscal_year  inflation_adjustment
# 0         1959                13.937
# 1         1960                13.363
# 2         1961                12.948
# 3         1962                12.450
# 4         1963                12.029
# ..         ...                   ...
# 73        2031                 1.000
# 74        2032                 1.000
# 75        2033                 1.000
# 76        2034                 1.000
# 77        2035                 1.000
#
# [78 rows x 2 columns]

# %%
SELECT *
FROM mission_budgets
# Out:
#       mission fiscal_year       cost_type                   cost_group  \
# 0     Cassini        1990      Spacecraft   Development/Implementation
# 1     Cassini        1991  Launch Support  Launch Vehicle(s) & Support
# 2     Cassini        1991      Spacecraft   Development/Implementation
# 3     Cassini        1992  Launch Support  Launch Vehicle(s) & Support
# 4     Cassini        1992      Spacecraft   Development/Implementation
# ...       ...         ...             ...                          ...
# 1008  Voyager        2019      Operations   Operations & Data Analysis
# 1009  Voyager        2020      Operations   Operations & Data Analysis
# 1010  Voyager        2021      Operations   Operations & Data Analysis
# 1011  Voyager        2022      Operations   Operations & Data Analysis
# 1012  Voyager        2023      Operations   Operations & Data Analysis
#
#       cost_MUSD
# 0          29.5
# 1           2.4
# 2         143.0
# 3          20.1
# 4         210.7
# ...         ...
# 1008        5.8
# 1009        6.7
# 1010        6.5
# 1011        5.6
# 1012        5.1
#
# [1013 rows x 5 columns]

# %%
SELECT *
FROM mission_details
# Out:
#                             mission  \
# 0                           Cassini
# 1                           CONTOUR
# 2                              DART
# 3                           DAVINCI
# 4                              Dawn
# 5                       Deep Impact
# 6                      Deep Space 1
# 7                          EscaPADE
# 8                    Europa Clipper
# 9                           Galileo
# 10                          Genesis
# 11                            GRAIL
# 12                           Helios
# 13                          InSight
# 14                            Janus
# 15                             Juno
# 16                            LADEE
# 17                             Lucy
# 18                   Lunar Orbiters
# 19                 Lunar Prospector
# 20                Lunar Trailblazer
# 21                         Magellan
# 22                       Mariner 10
# 23                    Mariner 8 & 9
# 24  Mariner R (I & II) Venus fly-by
# 25      Mariner-Mars '64 (III & IV)
# 26     Mariner-Mars 1969 (VI & VII)
# 27           Mariner-Venus 1967 (V)
# 28             Mars Global Surveyor
# 29                    Mars Observer
# 30                     Mars Odyssey
# 31                  Mars Pathfinder
# 32                Mars Perseverance
# 33               Mars Sample Return
# 34                            MAVEN
# 35                              MER
# 36                        MESSENGER
# 37                           MPLMCO
# 38                              MRO
# 39                    MSL Curiosity
# 40                             NEAR
# 41                     New Horizons
# 42                       OSIRIS-REx
# 43                          Phoenix
# 44                  Pioneer 10 & 11
# 45                    Pioneer 6 - 9
# 46                    Pioneer Venus
# 47                           Psyche
# 48                           Ranger
# 49                         Stardust
# 50                   Surveyor 1 - 7
# 51                           Viking
# 52                            VIPER
# 53                          Voyager
#
#                                     mission_full_name    destination  \
# 0                                     Cassini-Huygens  Outer Planets
# 1                                  COmet Nucleus TOUR   Small Bodies
# 2                    Double Asteroid Redirection Test   Small Bodies
# 3   Deep Atmosphere Venus Investigation of Noble g...          Venus
# 4                                                Dawn   Small Bodies
# 5                                         Deep Impact   Small Bodies
# 6                                        Deep Space 1   Small Bodies
# 7   Escape and Plasma Acceleration and Dynamics Ex...           Mars
# 8                                      Europa Clipper  Outer Planets
# 9                                             Galileo  Outer Planets
# 10                                            Genesis   Earth-Sun L1
# 11           Gravity Recovery and Interior Laboratory       The Moon
# 12                                             Helios        The Sun
# 13                                            InSight           Mars
# 14                                              Janus   Small Bodies
# 15                                               Juno  Outer Planets
# 16     Lunar Atmosphere and Dust Environment Explorer       The Moon
# 17                                               Lucy   Small Bodies
# 18                                     Lunar Orbiters       The Moon
# 19                                   Lunar Prospector       The Moon
# 20                                  Lunar Trailblazer       The Moon
# 21                                           Magellan          Venus
# 22                                         Mariner 10        Mercury
# 23                                      Mariner 8 & 9           Mars
# 24                    Mariner R (I & II) Venus fly-by          Venus
# 25                        Mariner-Mars '64 (III & IV)           Mars
# 26                       Mariner-Mars 1969 (VI & VII)           Mars
# 27                             Mariner-Venus 1967 (V)          Venus
# 28                               Mars Global Surveyor           Mars
# 29                Mars Geoscience/Climatology Orbiter           Mars
# 30                                       Mars Odyssey           Mars
# 31                                    Mars Pathfinder           Mars
# 32                                  Mars Perseverance           Mars
# 33                                 Mars Sample Return           Mars
# 34     Mars Atmosphere and Volatile Evolution Mission           Mars
# 35                             Mars Exploration Rover           Mars
# 36  MErcury Surface, Space ENvironment, GEochemist...        Mercury
# 37             Mars Polar Lander/Mars Climate Orbiter           Mars
# 38                        Mars Reconnaissance Orbiter           Mars
# 39               Mars Scientific Laboratory Curiosity           Mars
# 40                     Near Earth Asteroid Rendezvous   Small Bodies
# 41                                       New Horizons   Small Bodies
# 42  Origins, Spectral Interpretation, Resource Ide...   Small Bodies
# 43                                            Phoenix           Mars
# 44                                    Pioneer 10 & 11  Outer Planets
# 45                                      Pioneer 6 - 9  Outer Planets
# 46                                      Pioneer Venus          Venus
# 47                                             Psyche   Small Bodies
# 48                                             Ranger       The Moon
# 49                                           Stardust   Small Bodies
# 50                                     Surveyor 1 - 7       The Moon
# 51                                             Viking           Mars
# 52    Volatiles Investigating Polar Exploration Rover       The Moon
# 53                                            Voyager  Outer Planets
#
#                             program
# 0
# 1                         Discovery
# 2          Solar System Exploration
# 3                         Discovery
# 4                         Discovery
# 5                         Discovery
# 6                     New Millenium
# 7                           SIMPLEx
# 8          Solar System Exploration
# 9
# 10                        Discovery
# 11                        Discovery
# 12                          Pioneer
# 13                        Discovery
# 14                          SIMPLEx
# 15                    New Frontiers
# 16  Lunar Discovery and Exploration
# 17                        Discovery
# 18                    Lunar Orbiter
# 19                        Discovery
# 20                          SIMPLEx
# 21
# 22                          Mariner
# 23                          Mariner
# 24                          Mariner
# 25                          Mariner
# 26                          Mariner
# 27                          Mariner
# 28                 Mars Exploration
# 29
# 30                 Mars Exploration
# 31                        Discovery
# 32                 Mars Exploration
# 33
# 34                 Mars Exploration
# 35                 Mars Exploration
# 36                        Discovery
# 37                 Mars Exploration
# 38                 Mars Exploration
# 39                 Mars Exploration
# 40                        Discovery
# 41                    New Frontiers
# 42                    New Frontiers
# 43                 Mars Exploration
# 44                          Pioneer
# 45                          Pioneer
# 46                          Pioneer
# 47                        Discovery
# 48                           Ranger
# 49                        Discovery
# 50                         Surveyor
# 51                           Viking
# 52  Lunar Discovery and Exploration
# 53                          Voyager

# %%
SELECT MIN(fiscal_year), MAX(fiscal_year)
FROM inflation
# Out:
#     min   max
# 0  1959  2035

# %% [markdown]
# This shows that we have our exploration form 1959 to 2035

# %% [markdown]
# ### Now, we will check for the total expenditure in all of our exploration

# %%
SELECT SUM("cost_MUSD") AS total_cost_MUSD
FROM mission_budgets
# Out:
#    total_cost_musd
# 0     41406.554506

# %% [markdown]
# Since inflation effects the total expenditure, so we have to adjust for it as well

# %%
SELECT SUM("cost_MUSD" * inflation_adjustment) AS adjusted_total_cost_MUSD
FROM mission_budgets as m
LEFT JOIN inflation as i
ON m.fiscal_year = i.fiscal_year
# Out:
#    total_cost_musd
# 0     80992.593983

# %% [markdown]
# ### Checking for the 3 most expensive mission

# %%
SELECT mission, SUM("cost_MUSD" * inflation_adjustment) AS adjusted_total_cost_MUSD
FROM mission_budgets as m
LEFT JOIN inflation as i
ON m.fiscal_year = i.fiscal_year
GROUP BY mission
ORDER BY adjusted_total_cost_MUSD DESC
LIMIT 3
# Out:
#           mission  adjusted_total_cost_musd
# 0          Viking               7208.541041
# 1  Surveyor 1 - 7               6333.910560
# 2         Cassini               5285.431955

# %% [markdown]
# ### Checking for the years in which we had the most expenditure

# %%
SELECT i.fiscal_year, SUM("cost_MUSD" * inflation_adjustment) AS adjusted_total_cost_MUSD
FROM mission_budgets as m
LEFT JOIN inflation as i
ON m.fiscal_year = i.fiscal_year
GROUP BY i.fiscal_year
ORDER BY adjusted_total_cost_MUSD DESC
# Out:
#    fiscal_year  adjusted_total_cost_musd
# 0         1974               2637.251406
# 1         1965               2620.062486
# 2         1966               2496.027447
# 3         1973               2443.451351
# 4         1964               2412.935820
# ..         ...                       ...
# 72        2033                149.593212
# 73        2032                149.590728
# 74        2030                149.516204
# 75        2034                128.050000
# 76        2035                128.050000
#
# [77 rows x 2 columns]

# %% [markdown]
# ### Checking on which destinations with respect to their expenditure

# %%
SELECT md.destination, 
SUM("cost_MUSD" * inflation_adjustment) AS adjusted_total_cost_MUSD
FROM mission_budgets as m
LEFT JOIN inflation as i
ON m.fiscal_year = i.fiscal_year
LEFT JOIN mission_details as md
on m.mission = md.mission
GROUP BY md.destination
ORDER BY adjusted_total_cost_MUSD DESC
# Out:
#      destination  adjusted_total_cost_musd
# 0           Mars              31725.348594
# 1  Outer Planets              21827.564786
# 2       The Moon              12982.887263
# 3   Small Bodies               7365.860162
# 4          Venus               4796.703011
# 5        Mercury               1519.605957
# 6   Earth-Sun L1                427.220100
# 7        The Sun                347.404110

# %% [markdown]
# ### Which group has the most expenditure

# %%
SELECT m.cost_group, 
SUM("cost_MUSD" * inflation_adjustment) AS adjusted_total_cost_MUSD
FROM mission_budgets as m
LEFT JOIN inflation as i
ON m.fiscal_year = i.fiscal_year
LEFT JOIN mission_details as md
on m.mission = md.mission
GROUP BY m.cost_group
ORDER BY adjusted_total_cost_MUSD DESC
# Out:
#                              cost_group  adjusted_total_cost_musd
# 0            Development/Implementation              28829.239652
# 1  Development/Implementation (incl LV)              16599.165600
# 2            Operations & Data Analysis              13421.083087
# 3                           Formulation               8770.964100
# 4           Launch Vehicle(s) & Support               7930.072962
# 5                 Science & Experiments               3777.250974
# 6  Project Management/Ground Operations               1664.817608

# %% [markdown]
# ### How much money was spent on each mission of mars

# %%
SELECT m.mission, 
SUM("cost_MUSD" * inflation_adjustment) AS adjusted_total_cost_MUSD
FROM mission_budgets as m
LEFT JOIN inflation as i
ON m.fiscal_year = i.fiscal_year
LEFT JOIN mission_details as md
on m.mission = md.mission
WHERE md.destination = 'Mars'
GROUP BY m.mission
ORDER BY adjusted_total_cost_MUSD DESC
# Out:
#                          mission  adjusted_total_cost_musd
# 0                         Viking               7208.541041
# 1             Mars Sample Return               4309.570000
# 2                  MSL Curiosity               3749.528800
# 3              Mars Perseverance               2977.926400
# 4                  Mars Observer               1767.490594
# 5                            MER               1587.334067
# 6                            MRO               1426.064600
# 7   Mariner-Mars 1969 (VI & VII)               1321.627043
# 8                  Mariner 8 & 9               1285.142968
# 9    Mariner-Mars '64 (III & IV)               1146.638881
# 10                  Mars Odyssey               1004.366700
# 11                       InSight                933.871400
# 12                         MAVEN                871.931300
# 13                       Phoenix                572.105500
# 14                        MPLMCO                511.757200
# 15          Mars Global Surveyor                497.807700
# 16               Mars Pathfinder                484.744400
# 17                      EscaPADE                 68.900000
